# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.data')

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
column = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]

# %%
df.columns=column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   class         149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
x=df.iloc[:,0:4]
y=df.iloc[:,4:]

# %%
x=pd.get_dummies(x)
y=pd.get_dummies(y)

# %%
x.astype(int)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0               4            3             1            0
# 1               4            3             1            0
# 2               4            3             1            0
# 3               5            3             1            0
# 4               5            3             1            0
# ..            ...          ...           ...          ...
# 144             6            3             5            2
# 145             6            2             5            1
# 146             6            3             5            2
# 147             6            3             5            2
# 148             5            3             5            1
#
# [149 rows x 4 columns]

# %%
y
# Out:
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# 0                 True                  False                 False
# 1                 True                  False                 False
# 2                 True                  False                 False
# 3                 True                  False                 False
# 4                 True                  False                 False
# ..                 ...                    ...                   ...
# 144              False                  False                  True
# 145              False                  False                  True
# 146              False                  False                  True
# 147              False                  False                  True
# 148              False                  False                  True
#
# [149 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=9)

# %%
X_train.shape,X_test.shape
y_train.shape,y_test.shape
# Out:
# ((104, 3), (45, 3))

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 67            6.2          2.2           4.5          1.5
# 6             5.0          3.4           1.5          0.2
# 68            5.6          2.5           3.9          1.1
# 35            5.5          3.5           1.3          0.2
# 73            6.4          2.9           4.3          1.3
# ..            ...          ...           ...          ...
# 125           6.2          2.8           4.8          1.8
# 56            4.9          2.4           3.3          1.0
# 148           5.9          3.0           5.1          1.8
# 92            5.0          2.3           3.3          1.0
# 126           6.1          3.0           4.9          1.8
#
# [104 rows x 4 columns]

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 76            6.7          3.0           5.0          1.7
# 89            5.5          2.6           4.4          1.2
# 135           6.3          3.4           5.6          2.4
# 103           6.5          3.0           5.8          2.2
# 123           6.7          3.3           5.7          2.1
# 37            4.4          3.0           1.3          0.2
# 26            5.2          3.5           1.5          0.2
# 3             5.0          3.6           1.4          0.2
# 107           6.7          2.5           5.8          1.8
# 9             5.4          3.7           1.5          0.2
# 25            5.0          3.4           1.6          0.4
# 70            6.1          2.8           4.0          1.3
# 97            5.1          2.5           3.0          1.1
# 90            6.1          3.0           4.6          1.4
# 39            5.0          3.5           1.3          0.3
# 80            5.5          2.4           3.7          1.0
# 31            5.2          4.1           1.5          0.1
# 139           6.7          3.1           5.6          2.4
# 100           5.8          2.7           5.1          1.9
# 47            5.3          3.7           1.5          0.2
# 28            4.7          3.2           1.6          0.2
# 27            5.2          3.4           1.4          0.2
# 110           6.4          2.7           5.3          1.9
# 20            5.1          3.7           1.5          0.4
# 53            6.5          2.8           4.6          1.5
# 75            6.8          2.8           4.8          1.4
# 43            5.1          3.8           1.9          0.4
# 69            5.9          3.2           4.8          1.8
# 8             4.9          3.1           1.5          0.1
# 85            6.7          3.1           4.7          1.5
# 98            5.7          2.8           4.1          1.3
# 127           6.4          2.8           5.6          2.1
# 23            4.8          3.4           1.9          0.2
# 88            5.5          2.5           4.0          1.3
# 78            5.7          2.6           3.5          1.0
# 81            5.8          2.7           3.9          1.2
# 55            6.3          3.3           4.7          1.6
# 45            5.1          3.8           1.6          0.2
# 118           6.0          2.2           5.0          1.5
# 7             4.4          2.9           1.4          0.2
# 17            5.7          3.8           1.7          0.3
# 111           6.8          3.0           5.5          2.1
# 60            5.9          3.0           4.2          1.5
# 44            4.8          3.0           1.4          0.3
# 102           6.3          2.9           5.6          1.8

# %%
y_train
# Out:
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# 67               False                   True                 False
# 6                 True                  False                 False
# 68               False                   True                 False
# 35                True                  False                 False
# 73               False                   True                 False
# ..                 ...                    ...                   ...
# 125              False                  False                  True
# 56               False                   True                 False
# 148              False                  False                  True
# 92               False                   True                 False
# 126              False                  False                  True
#
# [104 rows x 3 columns]

# %%
y_test
# Out:
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# 76               False                   True                 False
# 89               False                   True                 False
# 135              False                  False                  True
# 103              False                  False                  True
# 123              False                  False                  True
# 37                True                  False                 False
# 26                True                  False                 False
# 3                 True                  False                 False
# 107              False                  False                  True
# 9                 True                  False                 False
# 25                True                  False                 False
# 70               False                   True                 False
# 97               False                   True                 False
# 90               False                   True                 False
# 39                True                  False                 False
# 80               False                   True                 False
# 31                True                  False                 False
# 139              False                  False                  True
# 100              False                  False                  True
# 47                True                  False                 False
# 28                True                  False                 False
# 27                True                  False                 False
# 110              False                  False                  True
# 20                True                  False                 False
# 53               False                   True                 False
# 75               False                   True                 False
# 43                True                  False                 False
# 69               False                   True                 False
# 8                 True                  False                 False
# 85               False                   True                 False
# 98               False                   True                 False
# 127              False                  False                  True
# 23                True                  False                 False
# 88               False                   True                 False
# 78               False                   True                 False
# 81               False                   True                 False
# 55               False                   True                 False
# 45                True                  False                 False
# 118              False                  False                  True
# 7                 True                  False                 False
# 17                True                  False                 False
# 111              False                  False                  True
# 60               False                   True                 False
# 44                True                  False                 False
# 102              False                  False                  True

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# model = Sequential()
# model.add(Dense(44, input_shape = (X_train.shape[1],), activation='relu'))

# model.add(Dense(y_train.shape[1], activation='softmax'))
# # model.compile(optimizer='adam',loss='categorical_crossentropy',
#              metrics=['accuracy'])

# %%
# model.summary()

# %%
# history=model.fit(X_train,y_train,epochs=100,batch_size=32,validation_split=0.2)

# %%
# loss,acc=model.evaluate(X_test,y_test)

# %%
# model = Sequential()
# model.add(Dense(64, input_shape = (X_train.shape[1],), activation='relu'))
# model.add(Dense(128,activation='relu')),
# model.add(Dense(y_train.shape[1], activation='softmax'))
# model.compile(optimizer='adam',loss='categorical_crossentropy',
#              metrics=['accuracy'])

# %%
# model.summary()

# %%
# history=model.fit(X_train,y_train,epochs=100,batch_size=16,validation_split=0.2)

# %%
# import keras
# from matplotlib import pyplot as plt
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %%
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# %%
# loss,acc=model.evaluate(X_test,y_test)

# %%
model = Sequential()
model.add(Dense(32, input_shape = (X_train.shape[1],), activation='relu'))
model.add(Dense(64,activation='relu')),
model.add(Dense(128,activation='relu')),
model.add(Dense(y_train.shape[1], activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',
             metrics=['accuracy'])
# Out:
# C:\Users\ACER\anaconda3\envs\ai\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,979 (42.89 KB)
#  Trainable params: 10,979 (42.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train,y_train,epochs=100,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 331ms/step - accuracy: 0.3718 - loss: 1.1996 - val_accuracy: 0.2857 - val_loss: 1.1230
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3484 - loss: 1.0940 - val_accuracy: 0.4762 - val_loss: 1.0303
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3505 - loss: 1.0389 - val_accuracy: 0.4762 - val_loss: 0.9802
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3349 - loss: 1.0187 - val_accuracy: 0.5714 - val_loss: 0.9470
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5370 - loss: 0.9777 - val_accuracy: 0.6667 - val_loss: 0.9193
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6673 - loss: 0.9415 - val_accuracy: 0.7143 - val_loss: 0.8965
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6907 - loss: 0.9024 - val_accuracy: 0.7143 - val_loss: 0.8737
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.6477 - loss: 0.8797 - val_accuracy: 0.7143 - val_loss: 0.8487
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6580 - loss: 0.8408 - val_accuracy: 0.8571 - val_loss: 0.8155
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8230 - loss: 0.7848 - val_accuracy: 0.7619 - val_loss: 0.7677
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6772 - loss: 0.7353 - val_accuracy: 0.7619 - val_loss: 0.7242
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7045 - loss: 0.6785 - val_accuracy: 0.7143 - val_loss: 0.6758
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6438 - loss: 0.6482 - val_accuracy: 0.7619 - val_loss: 0.6346
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6694 - loss: 0.5974 - val_accuracy: 0.7143 - val_loss: 0.5916
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6577 - loss: 0.5577 - val_accuracy: 0.8095 - val_loss: 0.5531
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6928 - loss: 0.5201 - val_accuracy: 0.8095 - val_loss: 0.5200
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7290 - loss: 0.4928 - val_accuracy: 0.9048 - val_loss: 0.5008
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8950 - loss: 0.4448 - val_accuracy: 1.0000 - val_loss: 0.4920
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9368 - loss: 0.4524 - val_accuracy: 1.0000 - val_loss: 0.4675
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9486 - loss: 0.4511 - val_accuracy: 0.9524 - val_loss: 0.4432
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.